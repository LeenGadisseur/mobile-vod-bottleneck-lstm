# %%
run test_train.py
# Out:
# 2021-04-22 12:11:33,499 - root - INFO - Use Cuda.
# 2021-04-22 12:11:33,500 - root - INFO - Namespace(base_net_lr=None, batch_size=2, cache_path='/media/leen/Acer_500GB_HDD/EPFL/', checkpoint_folder='models/', datasets='/media/leen/Acer_500GB_HDD/EPFL/', debug_steps=100, freeze_net=False, gamma=0.1, lr=0.0003, milestones='80,100', momentum=0.9, net='mobv2-ssdl-lstm4', num_epochs=200, num_workers=4, pretrained=None, pretrained_base_net='models/mb2-ssd-lite-mp-0_686.pth', resume=None, scheduler='multi-step', sequence_length=10, ssd_lr=None, t_max=120, use_cuda=True, validation_epochs=5, weight_decay=0.0005, width_mult=1.0)
# 2021-04-22 12:11:33,501 - root - INFO - Prepare training and val datasets.
# Cache file:  /media/leen/Acer_500GB_HDD/EPFL/train_EPFL_seq_gt_db.pkl
# Cached.
# Loading annos...
# 2021-04-22 12:11:55,337 - root - INFO - wrote gt roidb to /media/leen/Acer_500GB_HDD/EPFL/train_EPFL_seq_gt_db.pkl
# Cache file:  /media/leen/Acer_500GB_HDD/EPFL/val_EPFL_seq_gt_db.pkl
# ...
